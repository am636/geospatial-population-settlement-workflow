# %% [markdown]
# # Copperbelt, Zambia — Population distribution by settlement type
# *WorldPop 2020 constrained × GHS‑SMOD (L2→L1) × GADM 4.1 ADM2*
#
# **Purpose**: interview-friendly narrative + reproducible outputs.

# %% [markdown]
# ## Contents
# 1. Task 1 — Inputs & metadata
# 2. Task 2 — Boundary QA
# 3. Task 3 — Population totals
# 4. Task 4 — SMOD L2→L1 + harmonisation
# 5. Task 5 — Dominant class by area
# 6. Task 6 — Population by class
# 7. QA + discussion notes

# %% [markdown]
# ## Task 1 — Inputs and metadata
# **Question**: What are the datasets and implications?
#
# **Answer**: rasters differ in CRS/grid; SMOD is categorical so use nearest neighbour; keep WorldPop grid fixed for population totals.
#
# ➡️ `notebooks/00_sanity_check.ipynb`

# %% [markdown]
# ## Task 2 — Boundary QA
# Duplicate geometry + out-of-scope Mushindano; document issues; keep raw unchanged.
#
# ➡️ `notebooks/01_boundary_QA.ipynb`

# %% [markdown]
# ## Task 3 — Total population per ADM2
# Zonal sum on WorldPop grid; exclude NoData.
#
# ➡️ `notebooks/03_task3_total_population_by_adm2.ipynb`

# %% [markdown]
# ## Task 4 — SMOD L2→L1 and harmonisation plan
# Recode (11–13→1, 21–23→2, 30→3; water/other→NoData), keep Int16; align SMOD to WorldPop grid (NN) for pop-by-class.
#
# ➡️ `notebooks/04_recode_SMOD_L2_to_L1.ipynb`

# %% [markdown]
# ## Task 5 — Dominant class by area
# On SMOD equal-area grid, zonal histogram cell counts per ADM2.
#
# ➡️ `notebooks/05_dominant_smodL1_by_adm2_cellcounts.ipynb`

# %% [markdown]
# ## Task 6 — Population by class within ADM2
# Resample SMOD L1 to WorldPop grid (NN) → mask population → zonal sums → proportions + closure check.
#
# ➡️ `notebooks/06_pop_by_smodL1_class_within_adm2_copperbelt.ipynb`

# %% [markdown]
# ## QGIS exports
# Export layouts to `outputs/qgis/` and embed them here.
#
# ![QGIS map](../outputs/qgis/map_overview.png)
